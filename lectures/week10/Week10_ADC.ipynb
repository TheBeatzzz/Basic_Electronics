# %% [markdown]
# # Week 10-11: Analog to Digital Conversion
#
# ## Topics:
# - Voltage Comparators
# - Digital Bits
# - Quantization
# - Bit Depth (8/10/12/16-bit)
# - Sampling Theorem
# - Photodetectors
# - Data Acquisition
#
# ## LAB: Smart Car Final Project
#
# ---

# %% [markdown]
# ## Setup

# %%
# !pip install matplotlib numpy scipy -q

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

plt.style.use("seaborn-v0_8-darkgrid")
# %matplotlib inline

# %% [markdown]
# ## Interactive Simulations
#
# This notebook contains interactive Python simulations for  Analog to Digital Conversion

# %% [markdown]
# ## Summary
#
# Complete exercises and experiments in this notebook to master  Analog to Digital Conversion!
