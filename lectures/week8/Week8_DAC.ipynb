# %% [markdown]
# # Week 8-9: Digital to Analog Conversion
#
# ## Topics:
# - Digital Output
# - 7-Segment Displays
# - PWM Control
# - Sensor Reading
# - Digital Clocks
# - Counters and Timing
# - Waveform Generation
#
# ## LAB: Laser Scanning System
#
# ---

# %% [markdown]
# ## Setup

# %%
# !pip install matplotlib numpy scipy -q

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

plt.style.use("seaborn-v0_8-darkgrid")
# %matplotlib inline

# %% [markdown]
# ## Interactive Simulations
#
# This notebook contains interactive Python simulations for  Digital to Analog Conversion

# %% [markdown]
# ## Summary
#
# Complete exercises and experiments in this notebook to master  Digital to Analog Conversion!
