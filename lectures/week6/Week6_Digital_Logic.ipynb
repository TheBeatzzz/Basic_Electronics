# %% [markdown]
# # Week 6-7: Digital Signal and Logic Gates
#
# ## Topics:
# - Digital Signals vs Analog
# - Logic Gates (AND, OR, NOT, NAND, NOR, XOR, XNOR)
# - Truth Tables
# - Boolean Algebra
# - Combinational Logic
# - Sequential Logic
#
# ## LAB: Smart Home Controller
#
# ---

# %% [markdown]
# ## Setup

# %%
# !pip install matplotlib numpy scipy -q

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

plt.style.use("seaborn-v0_8-darkgrid")
# %matplotlib inline

# %% [markdown]
# ## Interactive Simulations
#
# This notebook contains interactive Python simulations for  Digital Signal and Logic Gates

# %% [markdown]
# ## Summary
#
# Complete exercises and experiments in this notebook to master  Digital Signal and Logic Gates!
